# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('BankChurners.csv')
data.head(5)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
data.isnull().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %%
# Checking basic descriptive statistics for numeric and categorical variables.

data.describe(include="all").T.sort_values.by(['unique'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-15d3580291b7> in <module>
#       1 # Checking basic descriptive statistics for numeric and categorical variables.
#       2
# ----> 3 data.describe(include="all").T.sort_values.by(['unique'])
#
# AttributeError: 'function' object has no attribute 'by'

# %%
data.describe(include="all").T.sort_values(by=["unique"])
# Out:
#                                                     count unique  \
# Attrition_Flag                                      10127      2
# Gender                                              10127      2
# Marital_Status                                      10127      4
# Card_Category                                       10127      4
# Income_Category                                     10127      6
# Education_Level                                     10127      7
# CLIENTNUM                                           10127    NaN
# Customer_Age                                        10127    NaN
# Dependent_count                                     10127    NaN
# Months_on_book                                      10127    NaN
# Total_Relationship_Count                            10127    NaN
# Months_Inactive_12_mon                              10127    NaN
# Contacts_Count_12_mon                               10127    NaN
# ...

# %%
list(data.columns)
# Out:
# ['CLIENTNUM',
#  'Attrition_Flag',
#  'Customer_Age',
#  'Gender',
#  'Dependent_count',
#  'Education_Level',
#  'Marital_Status',
#  'Income_Category',
#  'Card_Category',
#  'Months_on_book',
#  'Total_Relationship_Count',
#  'Months_Inactive_12_mon',
#  'Contacts_Count_12_mon',
#  'Credit_Limit',
#  'Total_Revolving_Bal',
#  'Avg_Open_To_Buy',
#  'Total_Amt_Chng_Q4_Q1',
#  'Total_Trans_Amt',
#  'Total_Trans_Ct',
#  'Total_Ct_Chng_Q4_Q1',
#  'Avg_Utilization_Ratio',
#  'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#  'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2']

# %%
data = data.drop(['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'], axis=1)

# %%
data.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %%
data.Attrition_Flag.unique()
# Out:
# array(['Existing Customer', 'Attrited Customer'], dtype=object)

# %%
data.Customer_Age.max(),data.Customer_Age.min()
# Out:
# (73, 26)

# %%
data.Customer_Age.unique()
# Out:
# array([45, 49, 51, 40, 44, 32, 37, 48, 42, 65, 56, 35, 57, 41, 61, 47, 62,
#        54, 59, 63, 53, 58, 55, 66, 50, 38, 46, 52, 39, 43, 64, 68, 67, 60,
#        73, 70, 36, 34, 33, 26, 31, 29, 30, 28, 27], dtype=int64)

# %%
data.Dependent_count.unique()
# Out:
# array([3, 5, 4, 2, 0, 1], dtype=int64)

# %%
data.Education_Level.unique()
# Out:
# array(['High School', 'Graduate', 'Uneducated', 'Unknown', 'College',
#        'Post-Graduate', 'Doctorate'], dtype=object)

# %%
data.Income_Category.unique()
# Out:
# array(['$60K - $80K', 'Less than $40K', '$80K - $120K', '$40K - $60K',
#        '$120K +', 'Unknown'], dtype=object)

# %%
data.Card_Category.unique()
# Out:
# array(['Blue', 'Gold', 'Silver', 'Platinum'], dtype=object)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True,fmt='.0%',cmap='twilight')
# Out:
# <AxesSubplot:>

# %%
categorical_columns = ['Marital_Status','Gender','Education_Level','Card_Category']
from sklearn.preprocessing import LabelEncoder

for col in categorical_columns:
    le = LabelEncoder()
    le.fit(data[col])
    data[col] = le.transform(data[col])

# %%
data.head(3)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0  768805383  Existing Customer            45       1                3
# 1  818770008  Existing Customer            49       0                5
# 2  713982108  Existing Customer            51       1                3
#
#    Education_Level  Marital_Status Income_Category  Card_Category  \
# 0                3               1     $60K - $80K              0
# 1                2               2  Less than $40K              0
# 2                2               1    $80K - $120K              0
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# 1              44  ...                       1                      2
# 2              36  ...                       1                      0
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# ...

# %%
data.loc[:,'Churn'] = np.where((data['Attrition_Flag']== 'Attrited Customer'), "1", "0")
data.drop(['Attrition_Flag'],axis=1)
data.head(5)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0  768805383  Existing Customer            45       1                3
# 1  818770008  Existing Customer            49       0                5
# 2  713982108  Existing Customer            51       1                3
# 3  769911858  Existing Customer            40       0                4
# 4  709106358  Existing Customer            40       1                3
#
#    Education_Level  Marital_Status Income_Category  Card_Category  \
# 0                3               1     $60K - $80K              0
# 1                2               2  Less than $40K              0
# 2                2               1    $80K - $120K              0
# 3                3               3  Less than $40K              0
# 4                5               1     $60K - $80K              0
#
#    Months_on_book  ...  Contacts_Count_12_mon  Credit_Limit  \
# 0              39  ...                      3       12691.0
# ...

# %%
data = data.drop(['CLIENTNUM','Attrition_Flag'],axis=1)

# %%
data["Income_Category"]=data['Income_Category'].replace({"Unknown": 0,
                                                           "Less than $40K":1,
                                                           "$40K - $60K":2,
                                                           "$60K - $80K":3,
                                                           "$80K - $120K":4,
                                                           "$120K +":5})

df2["Churn"]=df2["Churn"].astype('int64')

# %%
df2 = data.copy()

# %%
def boxplot_churn(nums, data):   
    
    fig, axes = plt.subplots(7, 2, figsize=(14,22))
#     print(axes)
    axes = axes.flatten()
#     print(axes)
    fig.suptitle('Box Plots for Numerical Features',fontsize=30)
    
    for ax, num in zip(axes, nums):
        sns.boxplot(y=num,data=data,ax=ax,color='#e74c3c')

# %%
num_col = ['Customer_Age', 'Dependent_count', 'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon', 'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal', 'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt', 'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio']
boxplot_churn(num_col,df2)

# %%
df2["Churn"]=df2["Churn"].astype('int64')
df3 = df2.copy()

# Discretization
df3["Total_Amt_Chng_Q4_Q1_qcut"]=pd.qcut(df3["Total_Amt_Chng_Q4_Q1"],4)
df3["Total_Trans_Amt_qcut"]=pd.qcut(df3["Total_Trans_Amt"],4)
df3["Total_Ct_Chng_Q4_Q1_qcut"]=pd.qcut(df3["Total_Ct_Chng_Q4_Q1"],4)


df3.drop(["Customer_Age","Months_on_book",
          "Credit_Limit","Avg_Open_To_Buy",
          "Total_Amt_Chng_Q4_Q1","Total_Trans_Amt",
          "Total_Ct_Chng_Q4_Q1"],axis=1,inplace=True)

# %%
df4 = pd.get_dummies(df3,columns=['Gender','Marital_Status', 'Card_Category'])


df4.head()
# Out:
#    Dependent_count  Education_Level  Income_Category  \
# 0                3                3                3
# 1                5                2                1
# 2                3                2                4
# 3                4                3                1
# 4                3                5                3
#
#    Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0                         5                       1                      3
# 1                         6                       1                      2
# 2                         4                       1                      0
# 3                         3                       4                      1
# 4                         5                       1                      0
#
#    Total_Revolving_Bal  Total_Trans_Ct  Avg_Utilization_Ratio  Churn  ...  \
# 0                  777              42                  0.061      0  ...
# ...
